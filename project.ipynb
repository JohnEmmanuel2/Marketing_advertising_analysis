# %% [markdown]
# Predicting the audience and the demographic area has been done the code.

# %% [markdown]
# Marketing advertising analysis is the process of examining and evaluating both individual advertisements and broader marketing campaigns to understand their effectiveness, impact, and ROI. It involves using both qualitative and quantitative data to analyze elements like the target audience, messaging, visuals, and persuasive techniques to improve future strategies and maximize marketing budget performance.

# %% [markdown]
# Data Collection
# I collected a social media advertising dataset from sources like Kaggle, which offers several options such as the Social Media Ad Campaign Dataset or the Social Media Advertisement Performance dataset, each containing user demographics, ad metadata, and engagement data. To download, you can use the Kaggle API in a Jupyter Notebook by installing the Kaggle library, using your API key, and running the command kaggle datasets download [dataset_name]. The data is typically provided in a zip file that needs to be extracted.

# %%
import pandas as pd
data = pd.read_csv("Social_Media_Advertising.csv")
data

# %% [markdown]
# The info() and describe() are methods used to gain insights into a DataFrame's structure and content.

# %%
# View available columns and related info
data.info()
